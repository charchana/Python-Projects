# %% [markdown]
# # Question 8
# - Use nps_chat and wordlist corpus.
# - If you find a word in nps_chat but not in wordlist, it is considered an unusual word. (e.g. Heyyyy, gr8, 4ever can be considered unusual words for this analysis)
# - Find out how many unusual words people speak in chat (notice: usernames should not be counted)
# - Bonus: What if I want to  count : ) , : ( all these emoticons in. (optional)

# %%
import nltk

# %%
from nltk.corpus import nps_chat as nps
from nltk.corpus import words as wordList

# %%
# getting all the posts 
words = []
posts = nltk.corpus.nps_chat.xml_posts()

# %%
import lxml.etree # for reading xml
import xml.etree.ElementTree as ET # for getting attributes of xml

# %%
L= []
for p in posts: # looping the list of posts 
    xmlstr = ET.tostring(p, encoding='utf8', method='xml') # converting th epost to string
    L.append(xmlstr) # storing in the list

# %%
chatWords = []
for xml in L: # looping the list of string posts
    root = lxml.etree.fromstring(xml) # getting the root element
    for terminals in root.findall('terminals'): # looping the to find all the terminal tag
      word = terminals.find('t').attrib # getting the value of t tag 
      [chatWords.append(word.get('word')) for chats in word] # storing in the list to get the chat words

# %%
a = []
for w in chatWords: # looping the chat words to filter the user names from char words 
    if ((w[6:9] == '20s') or (w[6:9] == '30s') or (w[6:9] == '40s') or (w[6:9] == 'tee') or (w[6:9] == 'adu')):
        a.append(w) # storing the user names in a list
len(a)
# Out:
# 1020

# %%
for i in a : # looping the users list
    if i in chatWords: # checking whether the user is present in chat words
        chatWords.remove(i) # if true removing the users from the list
print(chatWords)
# Out:
# ['now', 'now', ':P', ':P', 'PART', 'PART', 'hey', 'hey', 'ah', 'ah', 'NICK', 'NICK', '.', '.', ':)', ':)', 'JOIN', 'JOIN', 'hi', 'hi', '26', '26', 'JOIN', 'JOIN', 'PART', 'PART', 'there', 'there', 'do', 'do', 'fuck', 'fuck', 'whats', 'whats', 'PART', 'PART', 'PART', 'PART', 'i', 'i', 'PART', 'PART', 'and', 'and', 'that', 'that', 'any', 'any', '26', '26', 'JOIN', 'JOIN', 'my', 'my', 'PART', 'PART', '24', '24', 'boo', 'boo', '26', '26', 'lol', 'lol', 'boo', 'boo', 'JOIN', 'JOIN', 'PART', 'PART', 'he', 'he', 'boo', 'boo', 'hope', 'hope', 'PART', 'PART', 'ewwwww', 'ewwwww', '&', '&', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'sounds', 'sounds', 'r', 'r', 'JOIN', 'JOIN', 'PART', 'PART', 'I', 'I', '&', '&', 'ya', 'ya', 'I', 'I', 'heeeey', 'heeeey', 'do', 'do', '26', '26', 'you', 'you', 'yep', 'yep', 'Any', 'Any', 'hurry', 'hurry', 'PART', 'PART', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'not', 'not', 'a', 'a', 'JOIN', 'JOIN', 'well', 'well', 'my', 'my', 'Anyone', 'Anyone', 'hey', 'hey', 'as', 'as', 'is', 'is', 'PART', 'PART', 'hey', 'hey', 'PART', 'PART', 'JOIN', 'JOIN', 'and', 'and', 'ok', 'ok', 'yes', 'yes', 'fire', 'fire', 'Any', 'Any', 'JOIN', 'JOIN', 'PART', 'PART', 'and', 'and', 'JOIN', 'JOIN', 'yo', 'yo', 'or', 'or', 'are', 'are', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'show', 'show', 'let', 'let', 'PART', 'PART', ':)', ':)', 'haha', 'haha', 'brb', 'brb', 'opps', 'opps', 'JOIN', 'JOIN', 'PART', 'PART', 'sho', 'sho', '.', '.', 'hey', 'hey', '.', '.', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'any', 'any', 'hi', 'hi', 'boo', 'boo', 'hey', 'hey', 'PART', 'PART', 'i', 'i', 'PART', 'PART', '24', '24', 'where', 'where', 'sure', 'sure', 'JOIN', 'JOIN', 'what', 'what', 'i', 'i', 'yeee', 'yeee', 'im', 'im', 'JOIN', 'JOIN', 'i', 'i', 'hi', 'hi', 'wb', 'wb', 'u', 'u', 'PART', 'PART', 'PART', 'PART', 'JOIN', 'JOIN', 'single', 'single', 'JOIN', 'JOIN', 'ty', 'ty', 'PART', 'PART', 'JOIN', 'JOIN', 'Hi', 'Hi', 'PART', 'PART', 'JOIN', 'JOIN', 'hi', 'hi', 'HAHAHA', 'HAHAHA', 'yw', 'yw', 'you', 'you', 'alright', 'alright', 'hi', 'hi', 'you', 'you', 'i', 'i', 'hi', 'hi', 'lmao', 'lmao', 'ahah', 'ahah', 'PART', 'PART', 'Hi', 'Hi', 'in', 'in', '.', '.', 'cya', 'cya', 'single', 'single', 'ca', 'ca', 'JOIN', 'JOIN', 'hi', 'hi', 'bye', 'bye', 'well', 'well', 'yeah', 'yeah', ':)', ':)', 'answers', 'answers', 'I', 'I', 'iamahotnipwithpics', 'iamahotnipwithpics', 'first', 'first', 'PART', 'PART', 'JOIN', 'JOIN', 'uh', 'uh', 'A', 'A', 'make', 'make', 'lol', 'lol', 'Hi', 'Hi', '.', '.', 'right', 'right', 'i', 'i', 'OOooOO', 'OOooOO', 'how', 'how', 'lmaoo', 'lmaoo', "'", "'", "'", "'", 'how', 'how', 'any', 'any', 'off', 'off', 'really', 'really', 'Just', 'Just', 'that', 'that', 'wow', 'wow', 'PART', 'PART', 'hiya', 'hiya', 'lmao', 'lmao', 'im', 'im', 'omg', 'omg', 'Finger', 'Finger', 'I', 'I', 'didnt', 'didnt', 'finger', 'finger', 'yay', 'yay', 'PART', 'PART', 'that', 'that', 'oh', 'oh', 'PART', 'PART', 'JOIN', 'JOIN', 'geeshhh', 'geeshhh', 'lol', 'lol', 'PART', 'PART', 'hes', 'hes', 'ppl', 'ppl', '!', '!', '.', '.', 'you', 'you', '.', '.', 'any', 'any', 'please', 'please', 'Only', 'Only', 'ima', 'ima', 'yes', 'yes', 'PART', 'PART', 'aww', 'aww', 'forwads', 'forwads', 'i', 'i', 'theres', 'theres', 'JOIN', 'JOIN', 'so', 'so', 'thanks', 'thanks', 'forwads', 'forwads', 'JOIN', 'JOIN', '22', '22', 'can', 'can', 'lol', 'lol', 'forwards', 'forwards', 'lol', 'lol', 'JOIN', 'JOIN', 'ALL', 'ALL', 'PART', 'PART', 'I', 'I', 'JOIN', 'JOIN', 'PART', 'PART', 'who', 'who', 'i', 'i', 'who', 'who', 'Depends', 'Depends', 'Hi', 'Hi', 'yep', 'yep', 'lmao', 'lmao', '.', '.', ':)', ':)', 'PART', 'PART', 'your', 'your', 'On', 'On', 'what', 'what', 'JOIN', 'JOIN', 'little', 'little', 'i', 'i', 'lolololll', 'lolololll', 'handle', 'handle', 'oh', 'oh', 'beeehave', 'beeehave', 'and', 'and', 'i', 'i', 'JOIN', 'JOIN', 'lol', 'lol', 'what', 'what', 'jerkettes', 'jerkettes', 'CO', 'CO', 'well', 'well', 'i', 'i', 'i', 'i', 'lol', 'lol', 'Jerketts', 'Jerketts', 'lmao', 'lmao', 'wtf', 'wtf', 'yah', 'yah', 'JOIN', 'JOIN', 'gi ...

# %%
wordList.fileids()  # getting the files of wordlist
# Out:
# ['en', 'en-basic']

# %%
setOfWords = wordList.words() # getting the words of the wordlist

# %%
unusualWords = []
for u in chatWords: # looping thw wordlist to get unusual words 
    if u not in setOfWords: # checking whether the word is present in the chat words
         unusualWords.append(u)
print(unusualWords)
# Out:
# [':P', ':P', 'PART', 'PART', 'NICK', 'NICK', '.', '.', ':)', ':)', 'JOIN', 'JOIN', '26', '26', 'JOIN', 'JOIN', 'PART', 'PART', 'fuck', 'fuck', 'PART', 'PART', 'PART', 'PART', 'PART', 'PART', '26', '26', 'JOIN', 'JOIN', 'PART', 'PART', '24', '24', '26', '26', 'lol', 'lol', 'JOIN', 'JOIN', 'PART', 'PART', 'PART', 'PART', 'ewwwww', 'ewwwww', '&', '&', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'sounds', 'sounds', 'JOIN', 'JOIN', 'PART', 'PART', '&', '&', 'heeeey', 'heeeey', '26', '26', 'Any', 'Any', 'PART', 'PART', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'Anyone', 'Anyone', 'PART', 'PART', 'PART', 'PART', 'JOIN', 'JOIN', 'ok', 'ok', 'Any', 'Any', 'JOIN', 'JOIN', 'PART', 'PART', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'PART', 'PART', ':)', ':)', 'haha', 'haha', 'brb', 'brb', 'opps', 'opps', 'JOIN', 'JOIN', 'PART', 'PART', '.', '.', '.', '.', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'PART', 'PART', 'PART', 'PART', '24', '24', 'JOIN', 'JOIN', 'yeee', 'yeee', 'im', 'im', 'JOIN', 'JOIN', 'wb', 'wb', 'PART', 'PART', 'PART', 'PART', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'ty', 'ty', 'PART', 'PART', 'JOIN', 'JOIN', 'Hi', 'Hi', 'PART', 'PART', 'JOIN', 'JOIN', 'HAHAHA', 'HAHAHA', 'yw', 'yw', 'lmao', 'lmao', 'ahah', 'ahah', 'PART', 'PART', 'Hi', 'Hi', '.', '.', 'cya', 'cya', 'JOIN', 'JOIN', ':)', ':)', 'answers', 'answers', 'iamahotnipwithpics', 'iamahotnipwithpics', 'PART', 'PART', 'JOIN', 'JOIN', 'uh', 'uh', 'lol', 'lol', 'Hi', 'Hi', '.', '.', 'OOooOO', 'OOooOO', 'lmaoo', 'lmaoo', "'", "'", "'", "'", 'Just', 'Just', 'PART', 'PART', 'hiya', 'hiya', 'lmao', 'lmao', 'im', 'im', 'omg', 'omg', 'Finger', 'Finger', 'yay', 'yay', 'PART', 'PART', 'PART', 'PART', 'JOIN', 'JOIN', 'geeshhh', 'geeshhh', 'lol', 'lol', 'PART', 'PART', 'hes', 'hes', 'ppl', 'ppl', '!', '!', '.', '.', '.', '.', 'Only', 'Only', 'ima', 'ima', 'PART', 'PART', 'aww', 'aww', 'forwads', 'forwads', 'JOIN', 'JOIN', 'forwads', 'forwads', 'JOIN', 'JOIN', '22', '22', 'lol', 'lol', 'lol', 'lol', 'JOIN', 'JOIN', 'ALL', 'ALL', 'PART', 'PART', 'JOIN', 'JOIN', 'PART', 'PART', 'Depends', 'Depends', 'Hi', 'Hi', 'lmao', 'lmao', '.', '.', ':)', ':)', 'PART', 'PART', 'On', 'On', 'JOIN', 'JOIN', 'lolololll', 'lolololll', 'beeehave', 'beeehave', 'JOIN', 'JOIN', 'lol', 'lol', 'jerkettes', 'jerkettes', 'CO', 'CO', 'lol', 'lol', 'Jerketts', 'Jerketts', 'lmao', 'lmao', 'wtf', 'wtf', 'JOIN', 'JOIN', 'awwwwww', 'awwwwww', '.', '.', 'PART', 'PART', '.', '.', 'JOIN', 'JOIN', ':(', ':(', 'lol', 'lol', 'noo', 'noo', 'PART', 'PART', 'PART', 'PART', 'heyy', 'heyy', 'boys', 'boys', 'JOIN', 'JOIN', 'Hmm', 'Hmm', 'Guess', 'Guess', 'PART', 'PART', 'JOIN', 'JOIN', 'Hmm', 'Hmm', 'PART', 'PART', 'What', 'What', 'JOIN', 'JOIN', 'ahahah', 'ahahah', 'Your', 'Your', '--------->', '--------->', 'Lmfao', 'Lmfao', 'dr', 'dr', 'PART', 'PART', 'Is', 'Is', 'aww', 'aww', 'PART', 'PART', '.', '.', 'JOIN', 'JOIN', '.', '.', 'hmph', 'hmph', 'lol', 'lol', 'PART', 'PART', 'JOIN', 'JOIN', '.', '.', '.', '.', 'lets', 'lets', 'PART', 'PART', 'lets', 'lets', 'JOIN', 'JOIN', 'lol', 'lol', 'im', 'im', 'ok', 'ok', 'JOIN', 'JOIN', 'Ug', 'Ug', 'il', 'il', 'lmao', 'lmao', 'bbl', 'bbl', 'PART', 'PART', 'LOL', 'LOL', 'lol', 'lol', 'hahah', 'hahah', '8082653953', '8082653953', 'K-Fed', 'K-Fed', '.', '.', 'lol', 'lol', 'JOIN', 'JOIN', '.', '.', 'JOIN', 'JOIN', 'rethinks', 'rethinks', 'lmaoooo', 'lmaoooo', 'Aw', 'Aw', 'lol', 'lol', 'Poor', 'Poor', '.', '.', '(', '(', 'PART', 'PART', 'PART', 'PART', 'sits', 'sits', 'Cum', 'Cum', 'lol', 'lol', '.', '.', 'JOIN', 'JOIN', 'asl', 'asl', 'You', 'You', 'JOIN', 'JOIN', '.', '.', 'lmaooo', 'lmaooo', '.', '.', 'ewwww', 'ewwww', 'lol', 'lol', 'ewwwwww', 'ewwwwww', 'PART', 'PART', 'owww', 'owww', 'PART', 'PART', 'JOIN', 'JOIN', '.', '.', 'PART', 'PART', 'ughhh', 'ughhh', 'IL', 'IL', '.', '.', '.', '.', 'pm', 'pm', 'gags', 'gags', 'Lmfao', 'Lmfao', '.', '.', '.', '.', 'Meep', 'Meep', '.', '.', 'lol', 'lol', 'beeeeehave', 'beeeeehave', 'Remember', 'Remember', '.', '.', 'jk', 'jk', 'JOIN', 'JOIN', '1-900-anal-sex', '1-90 ...

# %%
# displaying the number of unique unusual words
l = len(set(unusualWords))
print('Total number of unusual words people speak in chat are', l)
# Out:
# Total number of unusual words people speak in chat are 1088

# %%
# removing smileys for bonus points
smilyList = [':)',':(', ';)',':@',';P',':P', ':o',':-)',':-(',';-)',':-@','-_-'] #manually a list created for smiley

# %%
finalList = []
for s in unusualWords:
    if s not in smilyList:
        finalList.append(s)
print(finalList)
# Out:
# ['PART', 'PART', 'NICK', 'NICK', '.', '.', 'JOIN', 'JOIN', '26', '26', 'JOIN', 'JOIN', 'PART', 'PART', 'fuck', 'fuck', 'PART', 'PART', 'PART', 'PART', 'PART', 'PART', '26', '26', 'JOIN', 'JOIN', 'PART', 'PART', '24', '24', '26', '26', 'lol', 'lol', 'JOIN', 'JOIN', 'PART', 'PART', 'PART', 'PART', 'ewwwww', 'ewwwww', '&', '&', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'sounds', 'sounds', 'JOIN', 'JOIN', 'PART', 'PART', '&', '&', 'heeeey', 'heeeey', '26', '26', 'Any', 'Any', 'PART', 'PART', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'Anyone', 'Anyone', 'PART', 'PART', 'PART', 'PART', 'JOIN', 'JOIN', 'ok', 'ok', 'Any', 'Any', 'JOIN', 'JOIN', 'PART', 'PART', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'PART', 'PART', 'haha', 'haha', 'brb', 'brb', 'opps', 'opps', 'JOIN', 'JOIN', 'PART', 'PART', '.', '.', '.', '.', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'PART', 'PART', 'PART', 'PART', '24', '24', 'JOIN', 'JOIN', 'yeee', 'yeee', 'im', 'im', 'JOIN', 'JOIN', 'wb', 'wb', 'PART', 'PART', 'PART', 'PART', 'JOIN', 'JOIN', 'JOIN', 'JOIN', 'ty', 'ty', 'PART', 'PART', 'JOIN', 'JOIN', 'Hi', 'Hi', 'PART', 'PART', 'JOIN', 'JOIN', 'HAHAHA', 'HAHAHA', 'yw', 'yw', 'lmao', 'lmao', 'ahah', 'ahah', 'PART', 'PART', 'Hi', 'Hi', '.', '.', 'cya', 'cya', 'JOIN', 'JOIN', 'answers', 'answers', 'iamahotnipwithpics', 'iamahotnipwithpics', 'PART', 'PART', 'JOIN', 'JOIN', 'uh', 'uh', 'lol', 'lol', 'Hi', 'Hi', '.', '.', 'OOooOO', 'OOooOO', 'lmaoo', 'lmaoo', "'", "'", "'", "'", 'Just', 'Just', 'PART', 'PART', 'hiya', 'hiya', 'lmao', 'lmao', 'im', 'im', 'omg', 'omg', 'Finger', 'Finger', 'yay', 'yay', 'PART', 'PART', 'PART', 'PART', 'JOIN', 'JOIN', 'geeshhh', 'geeshhh', 'lol', 'lol', 'PART', 'PART', 'hes', 'hes', 'ppl', 'ppl', '!', '!', '.', '.', '.', '.', 'Only', 'Only', 'ima', 'ima', 'PART', 'PART', 'aww', 'aww', 'forwads', 'forwads', 'JOIN', 'JOIN', 'forwads', 'forwads', 'JOIN', 'JOIN', '22', '22', 'lol', 'lol', 'lol', 'lol', 'JOIN', 'JOIN', 'ALL', 'ALL', 'PART', 'PART', 'JOIN', 'JOIN', 'PART', 'PART', 'Depends', 'Depends', 'Hi', 'Hi', 'lmao', 'lmao', '.', '.', 'PART', 'PART', 'On', 'On', 'JOIN', 'JOIN', 'lolololll', 'lolololll', 'beeehave', 'beeehave', 'JOIN', 'JOIN', 'lol', 'lol', 'jerkettes', 'jerkettes', 'CO', 'CO', 'lol', 'lol', 'Jerketts', 'Jerketts', 'lmao', 'lmao', 'wtf', 'wtf', 'JOIN', 'JOIN', 'awwwwww', 'awwwwww', '.', '.', 'PART', 'PART', '.', '.', 'JOIN', 'JOIN', 'lol', 'lol', 'noo', 'noo', 'PART', 'PART', 'PART', 'PART', 'heyy', 'heyy', 'boys', 'boys', 'JOIN', 'JOIN', 'Hmm', 'Hmm', 'Guess', 'Guess', 'PART', 'PART', 'JOIN', 'JOIN', 'Hmm', 'Hmm', 'PART', 'PART', 'What', 'What', 'JOIN', 'JOIN', 'ahahah', 'ahahah', 'Your', 'Your', '--------->', '--------->', 'Lmfao', 'Lmfao', 'dr', 'dr', 'PART', 'PART', 'Is', 'Is', 'aww', 'aww', 'PART', 'PART', '.', '.', 'JOIN', 'JOIN', '.', '.', 'hmph', 'hmph', 'lol', 'lol', 'PART', 'PART', 'JOIN', 'JOIN', '.', '.', '.', '.', 'lets', 'lets', 'PART', 'PART', 'lets', 'lets', 'JOIN', 'JOIN', 'lol', 'lol', 'im', 'im', 'ok', 'ok', 'JOIN', 'JOIN', 'Ug', 'Ug', 'il', 'il', 'lmao', 'lmao', 'bbl', 'bbl', 'PART', 'PART', 'LOL', 'LOL', 'lol', 'lol', 'hahah', 'hahah', '8082653953', '8082653953', 'K-Fed', 'K-Fed', '.', '.', 'lol', 'lol', 'JOIN', 'JOIN', '.', '.', 'JOIN', 'JOIN', 'rethinks', 'rethinks', 'lmaoooo', 'lmaoooo', 'Aw', 'Aw', 'lol', 'lol', 'Poor', 'Poor', '.', '.', '(', '(', 'PART', 'PART', 'PART', 'PART', 'sits', 'sits', 'Cum', 'Cum', 'lol', 'lol', '.', '.', 'JOIN', 'JOIN', 'asl', 'asl', 'You', 'You', 'JOIN', 'JOIN', '.', '.', 'lmaooo', 'lmaooo', '.', '.', 'ewwww', 'ewwww', 'lol', 'lol', 'ewwwwww', 'ewwwwww', 'PART', 'PART', 'owww', 'owww', 'PART', 'PART', 'JOIN', 'JOIN', '.', '.', 'PART', 'PART', 'ughhh', 'ughhh', 'IL', 'IL', '.', '.', '.', '.', 'pm', 'pm', 'gags', 'gags', 'Lmfao', 'Lmfao', '.', '.', '.', '.', 'Meep', 'Meep', '.', '.', 'lol', 'lol', 'beeeeehave', 'beeeeehave', 'Remember', 'Remember', '.', '.', 'jk', 'jk', 'JOIN', 'JOIN', '1-900-anal-sex', '1-900-anal-sex', 'lol', 'lol', 'hahah', 'hahah', 'lol', 'lol', 'LOLOLOLLL',  ...
