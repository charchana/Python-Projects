# %% [markdown]
# # Question 1
# - Under package Gutenberg, see what files are in it.
# - Find out how many words and how many unique words in file 'austen-persuasion.txt'.
# - Calculate the frequency for each words and show the top 10 most frequent words and their frequency.Try NOT to use FreqDist    module.
# - Keep the punctuation and stop words in this question.

# %%
import nltk

# %%
from nltk.corpus import gutenberg

# %%
nltk.corpus.gutenberg.fileids() # Get all file names in gutenberg
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
total_words = gutenberg.words(fileids ='austen-persuasion.txt') # Get the total words in 'austen-persuasion.txt' file

# %%
length_words = len(sorted(set(total_words))) # check the length of the words
unique_words = set(total_words)  # remove the duplicates from the words
print("Total number of unique words:", unique_words) 
uniqueWords = {} # Empty dictionary creation
# Out:
# Total number of unique words: {'include', 'unnecessarily', 'navy', 'minds', 'dictate', 'slighting', 'lend', 'besides', 'mantel', 'recollected', 'languor', 'beg', 'thinks', 'lower', 'respective', 'entire', 'gadding', 'quivering', 'priced', 'violation', 'sparingly', 'chill', 'spelt', 'inevitable', 'encouragement', 'strenuous', 'stairs', 'extinguish', 'water', 'dawdling', 'defer', 'strict', 'German', 'yet', 'but', 'scanty', 'supposed', 'province', 'compressed', 'unsuspicious', 'misunderstood', 'into', 'Heir', 'missed', 'blinds', 'St', 'pleasanter', 'proprieties', 'rivals', 'whom', 'firmly', 'procuring', 'inaccessible', 'musician', 'injury', 'deep', 'butcher', 'Everybody', 'gained', 'pensive', 'yielding', 'transposed', 'startled', 'quantity', 'environs', 'help', 'accounts', 'bed', 'flat', 'arise', 'quitted', 'quietly', 'ready', 'sufficiently', 'indisposed', 'stares', 'mahogany', 'noisy', 'wearing', 'comforted', 'sought', 'taking', 'restless', 'separation', '15', 'engagements', 'ennoble', 'non', 'beaten', 'devoting', 'worthy', 'received', 'prettiest', 'Rivers', 'overlooked', 'indignation', 'cuts', 'poetry', 'prospect', 'divisions', 'circumventing', 'precipitate', 'paternal', 'incumbent', 'Worse', 'arriving', 'barns', 'morrow', 'assuage', 'mixed', 'His', 'misconceived', 'Anything', 'mirrors', 'suited', 'humiliating', 'unimpaired', 'irresolute', 'Austen', 'below', 'True', 'Yours', 'decision', 'break', 'memorandums', 'anxiety', 'fall', 'confidential', 'grieving', 'hours', 'cease', 'grave', 'project', 'soon', 'cupboards', 'sources', 'Four', 'ground', 'news', 'assisting', 'residence', 'disagrees', 'shipwrecked', 'derived', 'ceremonious', 'accompanied', 'pass', 'visitor', 'gratify', 'utter', 'imbibed', 'cripple', 'false', 'shrubberies', 'remembrance', 'yes', 'together', 'consoling', 'murmur', 'OF', 'enter', 'apology', 'Instead', 'lectures', 'existing', 'elevated', 'uses', 'finished', 'dividing', 'manly', 'favourite', 'account', 'living', 'practices', 'safety', 'Warmth', 'parson', 'Dick', 'Crewkherne', 'ancient', 'scolding', 'unjust', 'yesterday', 'E', 'flurried', 'contracted', 'still', 'severe', 'Elliot', 'speedy', 'felt', 'spoke', 'apprehend', 'Laconia', 'retrenchment', 'note', 'On', 'wretchedly', 'recognising', 'avarice', 'hearts', 'recommendations', 'Wm', 'range', 'beautifier', 'escaping', 'recognise', 'act', 'disinterested', 'offering', 'part', 'privateers', 'baths', 'revel', 'Monkford', 'rule', 'military', 'rupture', 'slightest', 'bursts', 'alertness', 'receipt', 'night', 'this', 'obliged', 'all', 'unaffected', 'conveniently', 'gifted', 'burden', 'hazel', 'native', 'c', 'proportion', 'Go', 'somewhere', 'influence', 'suits', 'altered', 'elsewhere', 'blushing', '.', 'inconsolable', 'judges', 'himself', 'publicly', 'Ha', 'introduce', 'after', 'Stevenson', 'relationship', 'images', 'bid', 'insisting', 'and', 'twice', 'examined', 'road', 'hates', 'connecting', 'committed', 'claim', 'mainly', 'already', 'snatched', 'attempts', 'ways', 'courting', 'cousinly', 'swears', 'touch', 'inconstant', 'sincerely', 'voice', 'carelessness', 'consciousness', 'probability', 'embarrass', 'lines', 'rough', 'selves', 'manner', 'results', 'solitariness', 'uneventful', 'obligated', 'stood', 'continue', 'falling', 'rules', 'wiser', 'hers', 'formal', 'assorting', 'Lyme', 'Scott', 'Musgroves', 'hour', 'Thank', 'Wallis', 'motto', 'despair', 'Tell', 'recital', 'edify', 'bores', 'idly', 'lessons', 'trial', 'existed', 'implied', 'thence', 'grew', 'confessing', 'material', 'unexpected', 'favourer', 'involved', 'nights', 'finally', 'willing', 'pretensions', 'Union', 'explain', 'retrace', 'foul', 'moderation', 'groves', 'unaccountable', 'gratification', 'fit', 'esteem', 'proclaim', 'blue', 'materials', 'worked', 'ejaculations', 'pitch', 'Forty', 'For', 'riding', 'shelves', 'harmony', 'idle', 'hanging', 'proceeded', 'insignificant', 'pleasure', 'began', 'endurances', 'remainder', 'wrapt', 'grateful', 'beauty', 'Take', 'Pretty', 'knees', 'progress', 'chosen', 'thread',  ...

# %%
for word in total_words: # Loop all the words
    if word not in uniqueWords:
        uniqueWords[word] = 1   # if the word is not in the dictionary adding the word and setting a count
    else:
        uniqueWords[word] += 1  # incrementing the count if it's already presnt

# %%
sorted_list = []  # Empty list creation
convert_tuple = () # Empty tuple creation

# %%
for v in sorted( uniqueWords.values(), reverse = True):  # Loop through the sorted unique words by its values 
    for key in uniqueWords:
        if uniqueWords[ key ] ==  v: # Comparing if the key of the value is same 
            convert_tuple = key,v    # Adding the matched value to the tuple
            sorted_list.append(convert_tuple)  # Add the tuples to list to get the top 10 words
            break

# %%
print ("Top 10 most frequent words and their frequency:\n", sorted_list[:10])
# Out:
# Top 10 most frequent words and their frequency:
#  [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
