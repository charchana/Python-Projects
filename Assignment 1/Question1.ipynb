# %% [markdown]
# # Question 1
# - Under package Gutenberg, see what files are in it.
# - Find out how many words and how many unique words in file 'austen-persuasion.txt'.
# - Calculate the frequency for each words and show the top 10 most frequent words and their frequency.Try NOT to use FreqDist    module.
# - Keep the punctuation and stop words in this question.

# %%
import nltk

# %%
from nltk.corpus import gutenberg

# %%
nltk.corpus.gutenberg.fileids() # Get all file names in gutenberg
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
total_words = gutenberg.words(fileids ='austen-persuasion.txt') # Get the total words in 'austen-persuasion.txt' file

# %%
length_words = len(sorted(set(total_words))) # check the length of the words
unique_words = set(total_words)  # remove the duplicates from the words
print("Total number of unique words:", unique_words) 
uniqueWords = {} # Empty dictionary creation
# Out:
# Total number of unique words: {')', 'violence', 'resuming', 'owing', 'closet', 'protegee', 'officers', 'privileged', 'unobservant', 'simpleton', 'presence', 'failure', 'ye', 'tossed', 'pardoned', 'fragments', 'unable', 'resemble', 'lesson', 'managing', 'amicable', 'looked', 'enquiries', 'engaged', 'recommendation', 'unison', 'Sixty', 'tempt', 'occur', 'umbrella', 'attached', 'footsteps', 'declared', 'hide', 'Sidmouth', 'delicate', 'relations', 'fix', 'tribute', 'satisfied', 'absurd', 'merged', 'nevertheless', 'Thursday', 'headship', 'pins', 'rose', 'information', 'felicitous', 'throats', 'allayed', 'consumed', 'attacks', 'single', 'obscure', 'holding', 'houses', 'ask', 'perfectly', 'Till', 'indenture', 'carpet', 'vexation', 'shakes', 'Leave', 'heartiness', 'spoiled', 'dining', 'courting', 'prepared', 'oath', 'sprung', 'ideas', 'Talks', 'endurable', 'ever', 'matter', 'Dugdale', 'senseless', 'grievances', 'prompting', 'undeviating', 'weaken', 'treaty', 'justified', 'horribly', 'attributing', 'eligibilities', 'bowed', 'game', 'commanded', 'gladden', 'approaching', 'finances', 'trustiest', 'Within', 'soldier', 'rejoicing', 'tears', 'll', 'irrational', 'impressively', 'possessed', 'leaving', 'Eight', 'prove', 'Lord', 'evil', 'table', 'charities', 'beaten', 'uncertain', 'moderate', 'style', 'sheet', 'view', 'presume', 'momentary', 'fetching', 'rode', 'Market', 'Get', 'quantity', 'outlived', 'time', 'universal', 'beyond', 'heels', 'shrewd', 'defy', 'incapable', '?"', 'frights', 'suggestions', 'respectability', 'alienable', 'good', 'me', 'branches', 'books', 'shrink', 'ago', 'solely', 'lend', 'Atkinson', 'creature', 'entertain', 'On', 'doubted', 'mention', 'suffers', 'believed', 'affront', 'calculates', 'deficiencies', 'sighs', 'possessor', 'heedless', 'themselves', 'respective', 'drawn', 'answer', 'prettiness', 'forte', 'unsolicitous', 'it', 'quotation', 'envelope', 'marriages', 'seating', 'Intimately', 'proceeded', 'efficacy', 'exchange', 'undue', 'offence', 'poor', 'discretion', '?\'"', 'dependencies', 'borough', 'square', 'vouch', 'cart', 'sixteen', 'ribbons', 'advantages', 'serious', 'blinds', 'personally', 'attribute', 'original', 'present', 'solicitation', 'rapidly', 'way', 'invariably', 'reluctant', 'reply', 'moved', 'deputation', 'urgency', 'gained', 'incalculable', 'unvisited', 'desirable', 'arrived', 'curate', 'Pray', 'here', 'humiliating', 'variety', 'maids', 'anew', 'can', 'uprightness', 'laundry', 'accommodations', 'defend', 'luxuriant', 'prepare', 'gentle', 'straitened', 'translate', 'no', 'Laura', 'clear', 'Wight', 'scruple', 'madness', 'lamented', 'curl', 'individual', 'world', 'begun', '12', 'occasional', 'diversified', 'raised', 'avoiding', 'vanity', 'catch', 'Lansdown', 'crown', 'producing', 'lamenting', 'Lake', 'security', 'inns', 'sweeter', 'dressy', 'transmitted', 'more', 'disproportion', 'heard', 'dullest', 'usages', 'powder', 'sorry', 'hale', 'concerned', 'rupture', 'protestations', 'cannot', 'wherever', 'allow', 'His', 'winds', 'trying', 'accomplishments', 'furnish', 'Anything', 'shall', 'destination', 'certain', '1785', 'distinguish', 'all', 'shares', 'elasticity', 'strictest', 'proverbial', 'sank', 'Wm', 'influence', 'spot', 'jealousies', 'than', 'hang', 'upset', 'anecdotes', 'why', 'interfering', 'unnatural', 'strict', 'distant', 'beach', 'east', 'drew', 'dependence', 'July', 'approached', 'gives', 'parliaments', 'doctor', 'brightness', 'cold', 'occasionally', ']', 'rate', 'whole', 'staggering', 'doubting', 'losing', 'hammer', 'story', 'being', 'fancied', 'wild', ').', 'distresses', 'threw', 'permitted', 'blighted', 'grandson', 'sorrowing', 'descend', 'inhumanity', 'point', 'precious', 'contemptible', 'watch', 'respected', 'pockets', 'merits', 'changed', 'discoveries', 'shy', 'title', ');', 'noises', 'Gibraltar', 'operate', 'Each', 'occasion', 'preparations', 'compounded', 'case', 'Sunday', 'fare', 'bread', 'meditating', 'naturally', 'remnant', 'expose', 'beloved', 'objections', 'friends', 'supporting', 'd ...

# %%
for word in total_words: # Loop all the words
    if word not in uniqueWords:
        uniqueWords[word] = 1   # if the word is not in the dictionary adding the word and setting a count
    else:
        uniqueWords[word] += 1  # incrementing the count if it's already presnt

# %%
sorted_list = []  # Empty list creation
convert_tuple = () # Empty tuple creation

# %%
for v in sorted( uniqueWords.values(), reverse = True):  # Loop through the sorted unique words by its values 
    for key in uniqueWords:
        if uniqueWords[ key ] ==  v: # Comparing if the key of the value is same 
            convert_tuple = key,v    # Adding the matched value to the tuple
            sorted_list.append(convert_tuple)  # Add the tuples to list to get the top 10 words
            break

# %%
print ("Top 10 most frequent words and their frequency:", sorted_list[:10])
# Out:
# Top 10 most frequent words and their frequency: [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
