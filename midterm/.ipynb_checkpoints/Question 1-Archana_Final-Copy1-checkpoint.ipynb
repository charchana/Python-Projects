# %%
import glob
import os
import stop_words
import re
import email.utils
from operator import itemgetter
from os.path import isfile,isdir
from email.parser import Parser

# %%
rootdir = os.path.join(os.getcwd(),'maildir')
pathOfDirector = os.walk(rootdir)
directories =[direc[0] for direc in pathOfDirector]
len(directories)
# Out:
# 3453

# %%
def sentMailsPathList(directories):
    sentPath = []
    for directory in directories:
        if directory.endswith('_sent_mail'):
            sentPath.append(directory)
    return sentPath

# %%
sentpaths = sentMailsPathList(directories)
print(len(sentpaths))
# Out:
# 79

# %%
def yearlyMails(sentpaths):
    years_email = {}
    yearList = []
    for directory in sentpaths:
        sentMails = glob.glob(directory+ '\\' + '*')
        for mail in sentMails:
            if os.path.isfile(mail): 
                with open(mail,'r') as text_file:
                    email_data = text_file.read()
                    email_data= Parser().parsestr(email_data)
                    email_date = email.utils.parsedate(email_data['date'])
                    yearList.append(email_date[0])
                    year = email_date[0]
                    month = email_date[1]
                    if year not in years_email:
                        years_email[year] = {}
                        years_email[year][month] = 1
                        years_email[year]['counts'] = 1
                    else:
                        years_email[year]['counts'] += 1
                        if month not in years_email[year]:
                            years_email[year][month] = 1
                        else:
                            years_email[year][month] += 1
    return(years_email)

# %%
years= yearlyMails(sentpaths)
print(years)
# Out:
# {2000: {1: 763, 2: 688, 3: 926, 4: 825, 5: 878, 6: 1235, 7: 1447, 8: 1823, 9: 1915, 10: 2290, 11: 2387, 12: 2244, 'counts': 17421}, 2001: {1: 2438, 2: 2349, 3: 2409, 4: 2642, 5: 1458, 6: 289, 7: 7, 8: 8, 9: 18, 10: 7, 11: 9, 'counts': 11634}, 2002: {'counts': 22, 6: 1, 7: 21}, 1999: {12: 346, 'counts': 346}}

# %% [markdown]
# - From the above list we can conclude that
#     - for 2000 year, months 6 to 12 has highest mails
#     - for 2001 year, months 1 to 5 has highest mails
# - With this analysis we proceed further by analysising who are the persons involved in those highest mails

# %%
# Getting the months which has highest emails
year2000Months = []
year2001Months = []
for year in years.items():
    #print(year[0] == )
    if year[0] == 2000:
        #print("entering")
        for months in year[1].items():
            if months[1] > 1000:
                if months[0] != 'counts':
                    year2000Months.append(months[0])
    if year[0] == 2001:
        for months in year[1].items():
            if months[1] > 1000:
                if months[0] != 'counts':
                    year2001Months.append(months[0])

# %%
print("year 2000, months with highest mails:", year2000Months)
print("year 2001, months with highest mails:", year2001Months)
# Out:
# year 2000, months with highest mails: [6, 7, 8, 9, 10, 11, 12]
# year 2001, months with highest mails: [1, 2, 3, 4, 5]

# %%
def emailsSentByPersons(sentpaths,year2000Months,year2001Months):
    emailSendersReceivers ={}
    email_subject = ''
    for directory in sentpaths:
            sentMails = glob.glob(directory+ '\\' + '*')       
            for mail in sentMails:
                if os.path.isfile(mail): 
                    with open(mail,'r') as text_file:
                        email_data = text_file.read()
                        email_data= Parser().parsestr(email_data)
                        email_date = email.utils.parsedate(email_data['date'])
                        year = email_date[0]
                        month = email_date[1]
                        month_2000 = year2000Months
                        month_2001 = year2001Months
                        if (year == 2000 and month in month_2000) or (year == 2001 and month in month_2001):
                            email_subject = email_subject + email_data['subject']
                            email_to = email_data['to']
                            email_from = email_data['from']
                            if email_from not in emailSendersReceivers:
                                emailSendersReceivers[email_from] = {}
                                if email_to is not None:
                                    if',' in email_to:
                                        email_to.replace('/n','')
                                        email_to_list = email_to.split(',')
                                        email_to_1 = []
                                        for x in email_to_list:
                                            x = x.strip()
                                            email_to_1.append(x)
                                        for emails in email_to_1:
                                            if emails not in emailSendersReceivers[email_from]:
                                                emailSendersReceivers[email_from][emails] = 1
                                            else:
                                                emailSendersReceivers[email_from][emails] += 1
                                    else:
                                        emailSendersReceivers[email_from][email_to] = 1
                                emailSendersReceivers[email_from]['counts'] = 1
                            else:
                                emailSendersReceivers[email_from]['counts'] += 1
                                if email_to is not None:
                                    if',' in email_to:
                                        email_to.replace('/n','')
                                        email_to_list = email_to.split(',')
                                        email_to_1 = []
                                        for x in email_to_list:
                                            x = x.strip()
                                            email_to_1.append(x)
                                        for emails in email_to_1:
                                            if emails not in emailSendersReceivers[email_from]:
                                                emailSendersReceivers[email_from][emails] = 1
                                            else:
                                                emailSendersReceivers[email_from][emails] += 1
                                    else:
                                        if email_to not in emailSendersReceivers[email_from]:
                                            emailSendersReceivers[email_from][email_to] = 1
                                        else:
                                            emailSendersReceivers[email_from][email_to] += 1
                                        
    return emailSendersReceivers
#     for key in emailSendersReceivers:
#         print(key , '  ', emailSendersReceivers[key]['counts'])

# %%
numberMailsSent = emailsSentByPersons(sentpaths,year2000Months,year2001Months)

# %%
countOfPersonsMails = []
for persons in numberMailsSent.items():
        personsCount = []
        personsCount.append(persons[0])
        personsCount.append(persons[1]['counts'])
        countOfPersonsMails.append(personsCount)
sortedCountOfPersonMails = sorted(countOfPersonsMails, key=itemgetter(1), reverse = True)
top2 = sortedCountOfPersonMails[:2]
print("Top 2 persons who's communication are high:\n")
print(top2[0][0],":",top2[0][1], '\n')
print(top2[1][0],":",top2[1][1])
# Out:
# Top 2 persons who's communications are high:
#
# kay.mann@enron.com : 4096
#
# vince.kaminski@enron.com : 2589

# %% [markdown]
# - We analysed that Mann and Kaaminski has communicated more
# - Finally lets analyse what they were speaking about in those mails

# %%
mann = []
kaminski = []
for directory in sentpaths:
        sentMails = glob.glob(directory+ '\\' + '*')       
        for mail in sentMails:
            if os.path.isfile(mail): 
                with open(mail,'r') as text_file:
                    email_data = text_file.read()
                    email_data= Parser().parsestr(email_data)
                    email_date = email.utils.parsedate(email_data['date'])
                    year = email_date[0]
                    month = email_date[1]
                    month_2000 = year2000Months
                    month_2001 = year2001Months
                    if (year == 2000 and month in month_2000) or (year == 2001 and month in month_2001):
                        if email_data['from'] == 'kay.mann@enron.com':
                            mann.append(email_data['subject'])
                        if email_data['from'] == 'vince.kaminski@enron.com':
                            kaminski.append(email_data['subject'])
# Out:
# ['A resume for Londom', "Btu's Weekly Power Report", '', 'update on energy book', 'update on energy book', 'To_do', 'Latest draft', 'Re: Real Option Conference', 'Please, call George Posey', 'TRS', 'PLEASE NOTE THAT THE DATE FOR THE 1ST MEETING IS JANUARY 16', 'asking for advice regarding Summer Associate position at Enron', 'Re: asking for advice regarding Summer Associate position at Enron', 'Follow-up on SIAM Workshop', 'Forbidden and Secret Internet Files & Reports 83', 'Latest draft', 'Energy & Power Risk Management 2001, Houston', 'code', 'Re: Progress', 'Help with the Tiger Team', 'Phone conference', 'Request Submitted: Access Request for jennifer.n.stewart@enron.com', 'Re: Summer Intern', 'Re: Follow-up on SIAM Workshop', 'EPRM article', 'Anshuman - transfer from Dhabol', 'Re: Hi Vince', 'Interview Candidate', '2000 U.S. Collective Wisdom Portfolio (http: //psm20.mlpc.privnet.\n us.ml.com/logi', 'Re: Leonard Hilton Reception-DIRECTIONS-PARKING', 'Re: Continuation of Project Meeting', 'Re: VaR doc overview', 'Re: Reminder', 'Request Submitted: Access Request for jennifer.n.stewart@enron.com', 'Re: PRC Meeting Date', 'Stocks buys', 'Re-Schedule - Meeting - EAM VaR', '2000 International Collective Wisdom Portfolio (http: //psm20.mlpc\n .privnet.us.ml', 'Re: Meeting - EAM VaR', 'Re: Tiger Team Agenda', 'Re: Calling @2PM Me...4PM You', 'Meeting - EAM VaR', 'Re: scheduling companies for Mid-Project Reviews-Enron', 'Re: Transmission modelling', 'Re:', 'RE: ALP presentation', 'Re: Volume II of the Technical Corner Collection', 'Re: Volume II of the Technical Corner Collection', 'Re: Vacation', 'Re: Meeting on Feb 8, 2001', 'Re: order for book', 'Re: Fw: PSERC nuggets related to market Stem', 'Spring 2001 Module and Calendar Schedule Attached', 'Spring 2001 Module and Calendar Schedule Attached', '', 'Weather Person for London EGM', 'RE: ALP presentation', 'IAFE Update', 'Re: Reminder', 'Re: Action Learning Project Information', 'Action Learning Project Information', 'http://www.boxmind.com/default.asp', 'Re: PJM Training', 'Research Directory', 'Re: Meeting on Feb 8, 2001', 'IP technical document', 'Re: Comment?', 'Weather Knock Out Option (mean reverting + jump diffusion with mean\n reversion)', 'RE: Grant Masson', 'Research Group Party on January 6, 2001', 'Research Group Party on January 6, 2001', 'Btu Weekly', "Btu's Weekly Power Report", 'Contact info. during my vacation', 'Presentation', 'Re: Benchmarking Study', 'Power Plant Model', '', 'Re: Short Term Private Firm Model: Static historical\n snapshot+performance data for model development', 'Re: Henwood Stuff and Thoughts about Valuation', 'Time Change for Research Group Party on January 6, 2001', 'Re: Meeting Requested', 'Re: 1ST CHAPTER OF TRAINING BOOK', 'Re: Video Conference Call on Friday, January 12, 2001', 'Energy/Power Trader', 'IP technical document', 'Re: 1ST CHAPTER OF TRAINING BOOK', 'Re: Jim Stoessel Interview', 'Re: Sorry.', 'Btu Weekly', 'Re: Daniel Yergin on CERAWeek 2001: Shooting the Rapids', 'Re: Invitation...Welcome New Analyst Reception', 'Dhabol', 'EGM Staff Meeting - Reminder', 'Re: My model for spikes', 'Re: Tiger Team Event', 'Presentation', 'FW: HOW TO SURVIVE A HEART ATTACK WHEN ALONE', 'to do', 'Benchmarking Study', "Btu's Weekly Power Report", '', 'Re: Suggestion: implementing VAR based on non-normal log-returns\n simulations', 'Credit exposure model: review for Fri', 'L Xu', 'To Keith', 'Re: presentation', "Re: Associate and Analyst Programs New Year's Kickoff Reception", 'Re: CERA.com username and password', 'Sandeep', 'Re: CreditDotCom Projects', 'Btu Weekly', '', 'Warning system', '', 'Fwd curves', 'Petronas - a short courtesy meeting on Feb 8', 'Friday Brown Bag Lunch on Option Pricing', 'Meeting with Petronas', 'Re: VAR for business risk', 'Re: Meeting on Feb 8, 2001', 'Letetr for Hector', 'Valuation', 'RiskNews - RiskNews Update - 27/04/2001', 'Meeting on Feb 8, 2001', 'Mike Roberts', 'Re: Brief review of 2000 - the pipeline business' ...

# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
from nltk.stem import WordNetLemmatizer
import warnings
import gensim
import urllib.parse
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
from urllib.parse import urlparse
# Out:
# C:\Users\chint\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
tokenizer = RegexpTokenizer(r'\w+')
# create English stop words list
en_stop = get_stop_words('en')

# %%
# Create p_stemmer of class PorterStemmer
#p_stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
texts = []
listOfWords = ['forwarded', 'subject', 'mail', 'Original', 'Message', 'will']

for i in kaminski:
    raw = i.lower()
    http = re.sub(r"http\S+", ":", raw)
    forwardMessage = re.sub(r'(?m)^\-.*\n?', "", raw)
    tagRemoval = re.sub(r'subject.*|to.*|cc.*|from.*|sent by.*|.*@*,.+\n', "", forwardMessage)
    #totag = re.sub('^to:.*','', fromtag) 
    #subject = [line for line in forwardMessage if not "subject" in line]
    #to = [line for line in forwardMessage.split('\n' if not "to" in line]
    #subject = match = re.sub(r'[\w\.-]+@[\w\.-]+',"", forwardMessage)
    #print(tagRemoval)
    
    
    
    tokens = tokenizer.tokenize(tagRemoval)
    #print(tokens)
    isalpha = [i for i in tokens if  i.isalpha()]
    #print(tokens)
    shortwords = [word for word in isalpha if len(word)>3]
    #print(shortwords)
    removeWords = [i for i in shortwords if not i in listOfWords]
    # remove stop words from tokens
    stopped_tokens = [i for i in removeWords if not i in en_stop]
    # stem tokens
    stemmed_tokens = [wordnet_lemmatizer.lemmatize(i) for i in stopped_tokens]
    # add tokens to list
    #print(stemmed_tokens)
    texts.append(stemmed_tokens)
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)
#print(dictionary.token2id)
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
#print(corpus)
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=5, id2word = dictionary)
print(ldamodel.print_topics(num_topics=5, num_words=15))
# Out:
# [(0, '0.025*"rice" + 0.024*"request" + 0.019*"conference" + 0.018*"model" + 0.015*"price" + 0.014*"university" + 0.014*"presentation" + 0.011*"mgmt" + 0.011*"draft" + 0.011*"energy" + 0.011*"program" + 0.011*"option" + 0.010*"schedule" + 0.010*"call" + 0.009*"article"'), (1, '0.024*"presentation" + 0.022*"hello" + 0.017*"course" + 0.016*"book" + 0.015*"vince" + 0.015*"hous" + 0.013*"derivative" + 0.013*"california" + 0.013*"interview" + 0.011*"itinerary" + 0.011*"risk" + 0.011*"dinner" + 0.011*"electricity" + 0.011*"petronas" + 0.010*"approval"'), (2, '0.044*"weekly" + 0.043*"resume" + 0.026*"summer" + 0.026*"enron" + 0.025*"whar" + 0.024*"energy" + 0.023*"internship" + 0.016*"risk" + 0.015*"valuation" + 0.013*"model" + 0.012*"weather" + 0.012*"release" + 0.012*"message" + 0.012*"announces" + 0.011*"meeting"'), (3, '0.054*"enron" + 0.037*"power" + 0.035*"report" + 0.032*"weekly" + 0.017*"resume" + 0.017*"research" + 0.016*"class" + 0.013*"interview" + 0.013*"meeting" + 0.011*"review" + 0.011*"james" + 0.011*"valverde" + 0.010*"rice" + 0.009*"garp" + 0.009*"arrangement"'), (4, '0.030*"visit" + 0.018*"praca" + 0.018*"dyplomowa" + 0.017*"invitation" + 0.014*"benchmarking" + 0.012*"mgmt" + 0.011*"conference" + 0.010*"texas" + 0.010*"edycja" + 0.010*"address" + 0.010*"paper" + 0.010*"meeting" + 0.010*"austin" + 0.009*"roundtable" + 0.008*"warszawa"')]

# %%
def dataToWriteInCsvKaminski(kaminski):
texts = []
listOfWords = ['forwarded', 'subject', 'mail', 'Original', 'Message', 'will']

    for i in kaminski:
        raw = i.lower()
        http = re.sub(r"http\S+", ":", raw)
        forwardMessage = re.sub(r'(?m)^\-.*\n?', "", raw)
        tagRemoval = re.sub(r'subject.*|to.*|cc.*|from.*|sent by.*|.*@*,.+\n', "", forwardMessage)
        #totag = re.sub('^to:.*','', fromtag) 
        #subject = [line for line in forwardMessage if not "subject" in line]
        #to = [line for line in forwardMessage.split('\n' if not "to" in line]
        #subject = match = re.sub(r'[\w\.-]+@[\w\.-]+',"", forwardMessage)
        #print(tagRemoval)



        tokens = tokenizer.tokenize(tagRemoval)
        #print(tokens)
        isalpha = [i for i in tokens if  i.isalpha()]
        #print(tokens)
        shortwords = [word for word in isalpha if len(word)>3]
        #print(shortwords)
        removeWords = [i for i in shortwords if not i in listOfWords]
        # remove stop words from tokens
        stopped_tokens = [i for i in removeWords if not i in en_stop]
        # stem tokens
        stemmed_tokens = [wordnet_lemmatizer.lemmatize(i) for i in stopped_tokens]
        # add tokens to list
        #print(stemmed_tokens)
        texts.append(stemmed_tokens)
    # turn our tokenized documents into a id <-> term dictionary
    dictionary = corpora.Dictionary(texts)
    #print(dictionary.token2id)
    # convert tokenized documents into a document-term matrix
    corpus = [dictionary.doc2bow(text) for text in texts]
    #print(corpus)
    ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=5, id2word = dictionary)
    x = ldamodel.print_topics(num_topics=5, num_words=15)

return x
# Out:
# [(0, '0.042*"enron" + 0.030*"rice" + 0.026*"interview" + 0.021*"hello" + 0.017*"invitation" + 0.012*"university" + 0.012*"price" + 0.011*"james" + 0.011*"dinner" + 0.011*"petronas" + 0.010*"corner" + 0.010*"conference" + 0.010*"finance" + 0.010*"technical" + 0.009*"roundtable"'), (1, '0.039*"power" + 0.038*"report" + 0.032*"weekly" + 0.030*"presentation" + 0.026*"request" + 0.021*"meeting" + 0.019*"resume" + 0.018*"research" + 0.017*"model" + 0.012*"update" + 0.012*"review" + 0.011*"release" + 0.011*"approval" + 0.011*"project" + 0.010*"version"'), (2, '0.023*"option" + 0.017*"class" + 0.016*"hous" + 0.014*"california" + 0.014*"draft" + 0.013*"texas" + 0.012*"meeting" + 0.012*"address" + 0.010*"vacation" + 0.010*"reminder" + 0.009*"java" + 0.009*"valuation" + 0.009*"conference" + 0.008*"letter" + 0.008*"austin"'), (3, '0.035*"weekly" + 0.022*"energy" + 0.021*"paper" + 0.021*"course" + 0.019*"risk" + 0.016*"derivative" + 0.016*"visit" + 0.015*"enron" + 0.015*"book" + 0.015*"benchmarking" + 0.013*"weather" + 0.013*"eprm" + 0.012*"dyplomowa" + 0.012*"praca" + 0.012*"vince"'), (4, '0.042*"resume" + 0.033*"summer" + 0.029*"whar" + 0.026*"internship" + 0.016*"enron" + 0.014*"visit" + 0.010*"energy" + 0.009*"latest" + 0.009*"anshuman" + 0.008*"march" + 0.008*"london" + 0.008*"howard" + 0.008*"derivative" + 0.007*"research" + 0.007*"position"')]

# %%
def dataToWriteInCsvMann(mann):
texts = []
listOfWords = ['forwarded', 'subject', 'mail', 'Original', 'Message', 'will']

    for i in kaminski:
        raw = i.lower()
        http = re.sub(r"http\S+", ":", raw)
        forwardMessage = re.sub(r'(?m)^\-.*\n?', "", raw)
        tagRemoval = re.sub(r'subject.*|to.*|cc.*|from.*|sent by.*|.*@*,.+\n', "", forwardMessage)
        #totag = re.sub('^to:.*','', fromtag) 
        #subject = [line for line in forwardMessage if not "subject" in line]
        #to = [line for line in forwardMessage.split('\n' if not "to" in line]
        #subject = match = re.sub(r'[\w\.-]+@[\w\.-]+',"", forwardMessage)
        #print(tagRemoval)



        tokens = tokenizer.tokenize(tagRemoval)
        #print(tokens)
        isalpha = [i for i in tokens if  i.isalpha()]
        #print(tokens)
        shortwords = [word for word in isalpha if len(word)>3]
        #print(shortwords)
        removeWords = [i for i in shortwords if not i in listOfWords]
        # remove stop words from tokens
        stopped_tokens = [i for i in removeWords if not i in en_stop]
        # stem tokens
        stemmed_tokens = [wordnet_lemmatizer.lemmatize(i) for i in stopped_tokens]
        # add tokens to list
        #print(stemmed_tokens)
        texts.append(stemmed_tokens)
    # turn our tokenized documents into a id <-> term dictionary
    dictionary = corpora.Dictionary(texts)
    #print(dictionary.token2id)
    # convert tokenized documents into a document-term matrix
    corpus = [dictionary.doc2bow(text) for text in texts]
    #print(corpus)
    ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=5, id2word = dictionary)
    x = ldamodel.print_topics(num_topics=5, num_words=15)

return x

# %%
# function writing the csv file with restuarants details
def csvCreation(filename, crimeData):
    with open(filename, 'a',encoding='utf_8', errors='ignore') as outcsv: # opening a csv file as english file
        #configure writer to write standard csv file
        writer = csv.writer(outcsv, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL, lineterminator='\n')
        # writing the headers for the file
        writer.writerow(['YEAR', 'CRIMES HAPPENED'])
        for eachRes in crimeData.items():
            # writing the data row by row
            writer.writerow([eachRes[0],eachRes[1]])
for each in x:
    data = each[1]
    for one in data:
        c = re.findall(r'[0-9].', one)
        print(c)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
# check whether the directory is already created if not this function creates it
def dir_check(file_path):
    if not os.path.exists(file_path):
        os.makedirs(file_path) # creates the complete folder structure

# %%
# creating the csv file at specified path
def output(csvPath):
    if os.path.exists(csvPath):
        os.remove(csvPath) # removing the file if already present
        kaminski = dataToWriteInCsvkaminski(kaminski) # creating the restuarants data
        mann = dataToWriteInCsvkaminski(kaminski) # creating the restuarants data
        csvCreation(csvPath, kaminski) # creating the csv file
        csvCreation(csvPath, mann) # creating the csv file
    else:
        crimeData = dataToWriteInCsv(crimeFiles)  # creating the restuarants data
        csvCreation(csvPath, crimeData) # creating the csv file

# %%
csvFolder = os.path.join(path,'OutputFiles')
dir_check(csvFolder)
csvPath1 = os.path.join(csvFolder,'Q1Analysis3_TopicModelling_Mann.csv') # path is taken

# %%
output(csvPath) # calling the function to create csv file
