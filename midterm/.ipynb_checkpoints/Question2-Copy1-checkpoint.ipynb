# %% [markdown]
# # Question 2
# - You would need to create an API key.
# - Use request or beautiful-soap library to download the data. (No other library or crawler allowed).
# - Store the data in your local machine.
# - Your analysis should use this downloaded data only (and not try to redownload this data again during analysis time).
# - There is a rate limit for downloading the data. I would suggest you to start collecting the data from day 1. You can try using multiple account to get more than 1 key.
# - You need to use atleast 2 API method eg: archive, Article Search. Do not use Movies Review, Semantic API.

# %%
import os
nyt_archive_key1='da5635853dd94e19bdd946145bea0af4' #os.getenv('nyt_archive_key')
# print(nyt_archive_key)

# %%
def download_file(url):
    local_filename = url.split('/')[-1]
    r = requests.get(url, stream=True)
    with open(local_filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024): 
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                #f.flush() commented by recommendation from J.F.Sebastian
    return local_filename

# %%
def convert(input):
    if isinstance(input, dict):
        return {convert(key): convert(value) for key, value in input.items()}
    elif isinstance(input, list):
        return [convert(element) for element in input]
    else:
        return input

# %%
import requests
import json
import datetime
import time
import sys
import urllib
import urllib.error
import logging
from urllib.error import HTTPError
def getArticles(date,api_key, json_file_path):
    # LOOP THROUGH THE 101 PAGES NYTIMES ALLOWS FOR THAT DATE
    for page in range(101):
#         try:
        requested_string = "http://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date=" + date + "&end_date=" + date + "&page=" + str(page) + "&api-key=" + api_key
        response = requests.get(requested_string) #urlopen(request_string)
        print(type(response))
        #content = response.read().decode('utf-8')
        content = response.content.decode("utf-8")
        print(content)
        if content:
            #print(content)
            #r = json.loads(content)
            #print(r)
            articles = convert(json.loads(content))
            # if there are articles here
            #r = content["response"]
            #print(r)
            if len(articles["response"]["docs"]) >= 1:
                print("entering")
                json_file_name = getJsonFileName(date,page, json_file_path)
                json_file = open(json_file_name, 'w')
                json_file.write(content)
                json_file.close()
            # if no more articles, go to next date
            else:
                return
        else:
            break
        time.sleep(3)
#         except HTTPError as e:
#             logging.error("HTTPError on page %s on %s (err no. %s: %s) Here's the URL of the call: %s", page, date, e.code, e.reason, request_string)
#         except: 
#             logging.error("Error on %s page %s: %s",date,sys.exc_info()[0])
        #continue

# %%
# helper function to iterate through dates
def daterange( start_date, end_date ):
    if start_date <= end_date:
        for n in range( ( end_date - start_date ).days + 1 ):
            yield start_date + datetime.timedelta( n )
    else:
        for n in range( ( start_date - end_date ).days + 1 ):
            yield start_date - datetime.timedelta( n )

# %%
def getJsonFileName(date, page, json_file_path):
    json_file_name = ".".join([date,str(page),'json'])
    json_file_name = "".join([json_file_path,'\\',json_file_name])
    return json_file_name

# %%
def main():
    json_file_path = '/Users/rajusingh/NYTData'
    #csv_file_name = args.csv
    api_key = nyt_archive_key1    
    start = datetime.date( year = 2016, month = 11, day = 1 )
    end = datetime.date( year = 2016, month = 11, day = 2 )
    print(type(start))
    #query="trump"
    log_file = "".join([json_file_path,'\\',"getTimesArticles_testing.log"])
    #logging.basicConfig(log_file, level=logging.INFO)
 
    logging.info("Getting started.") 
#     try:
        # LOOP THROUGH THE SPECIFIED DATES
    for date in daterange( start, end ):
        date = date.strftime("%Y%m%d")
        logging.info("Working on %s." % date)
        getArticles(date,api_key,json_file_path)
        #parseArticles(date, csv_file_name, json_file_path)
#     except:
#         logging.error("Unexpected error: %s", str(sys.exc_info()[0]))
#     finally:
#         logging.info("Finished")

# %%
main()
# Out:
# <class 'datetime.date'>
# <class 'requests.models.Response'>
# {"response":{"meta":{"hits":852,"time":40,"offset":0},"docs":[{"web_url":"http:\/\/www.nytimes.com\/aponline\/2016\/11\/01\/us\/ap-fbc-notre-dame-players-arrested.html","snippet":"Two Notre Dame football players arrested on marijuana charges may avoid jail time and criminal records after reaching plea bargains with prosecutors....","lead_paragraph":"Two Notre Dame football players arrested on marijuana charges may avoid jail time and criminal records after reaching plea bargains with prosecutors.","abstract":null,"print_page":null,"blog":[],"source":"AP","multimedia":[],"headline":{"main":"2 Notre Dame Players May Avoid Jail for Marijuana Arrests","print_headline":"2 Notre Dame Players May Avoid Jail for Marijuana Arrests"},"keywords":[],"pub_date":"2016-11-01T23:57:48Z","document_type":"article","news_desk":null,"section_name":"U.S.","subsection_name":null,"byline":{"person":[],"original":"By THE ASSOCIATED PRESS","organization":"THE ASSOCIATED PRESS"},"type_of_material":"News","_id":"58192c0995d0e022439c680a","word_count":"137","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/aponline\/2016\/11\/01\/us\/politics\/ap-us-campaign-2016-johnson.html","snippet":"Hillary Clinton could face impeachment if she is elected president because her use of a private email server as secretary of state broke the law, Sen. Ron Johnson of Wisconsin said....","lead_paragraph":"Hillary Clinton could face impeachment if she is elected president because her use of a private email server as secretary of state broke the law, Sen. Ron Johnson of Wisconsin said.","abstract":null,"print_page":null,"blog":[],"source":"AP","multimedia":[],"headline":{"main":"Johnson: Clinton Could Be Impeached if Elected President","print_headline":"Johnson: Clinton Could Be Impeached if Elected President"},"keywords":[],"pub_date":"2016-11-01T23:57:45Z","document_type":"article","news_desk":null,"section_name":"U.S.","subsection_name":"Politics","byline":{"person":[],"original":"By THE ASSOCIATED PRESS","organization":"THE ASSOCIATED PRESS"},"type_of_material":"News","_id":"58192c0195d0e022439c6809","word_count":"251","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/2016\/11\/02\/world\/americas\/canada-patrick-lagace-montreal-police.html","snippet":"Investigators looking into corruption within the Montreal police force for almost six months focused their attention on a reporter who had no apparent connection to the case....","lead_paragraph":"Investigators looking into corruption within the Montreal police force for almost six months focused their attention on a reporter who had no apparent connection to the case.","abstract":"Advocates for freedom of press denounce Montreal police force for its surveillance of reporter Patrick Lagace; spying was apparently prompted by media leaks from within department about internal investigation into corruption.","print_page":"6","blog":[],"source":"The New York Times","multimedia":[],"headline":{"main":"Montreal Police Face a Storm of Criticism Over Surveillance of a Journalist","print_headline":"Montreal Police Face a Storm of Criticism Over Surveillance of a Journalist"},"keywords":[{"rank":"1","is_major":"Y","name":"subject","value":"Surveillance of Citizens by Government"},{"rank":"2","is_major":"Y","name":"subject","value":"Freedom of the Press"},{"rank":"3","is_major":"N","name":"organizations","value":"Supreme Court of Canada"},{"rank":"4","is_major":"Y","name":"glocations","value":"Montreal (Quebec)"},{"rank":"5","is_major":"N","name":"glocations","value":"Quebec Province (Canada)"},{"rank":"6","is_major":"Y","name":"persons","value":"Lagace, Patrick (1972- )"},{"rank":"7","is_major":"Y","name":"subject","value":"Police Brutality, Misconduct and Shootings"}],"pub_date":"2016-11-01T23:57:01Z","document_type":"article","news_desk":"Foreign","section_name":"World","subsection_name":"Americas","byline":{"person":[{"organization":"","role":"reported","firstname":"Ian","rank":1,"lastname":"AUSTEN"}], ...
# entering
# <class 'requests.models.Response'>
# {"response":{"meta":{"hits":852,"time":54,"offset":10},"docs":[{"web_url":"http:\/\/www.nytimes.com\/reuters\/2016\/11\/01\/business\/01reuters-brazil-corruption-trump-exclusive.html","snippet":"A Brazilian prosecutor has opened a criminal investigation into investments made by two state pension funds in a luxury Rio de Janeiro hotel that is part of the Trump franchise, according to a court filing reviewed by Reuters on Tuesday....","lead_paragraph":"A Brazilian prosecutor has opened a criminal investigation into investments made by two state pension funds in a luxury Rio de Janeiro hotel that is part of the Trump franchise, according to a court filing reviewed by Reuters on Tuesday.","abstract":null,"print_page":null,"blog":[],"source":"Reuters","multimedia":[],"headline":{"main":"Exclusive: Brazil Prosecutor Investigates Funds' Investment in Trump Hotel Rio","print_headline":"Exclusive: Brazil Prosecutor Investigates Funds' Investment in Trump Hotel Rio"},"keywords":[],"pub_date":"2016-11-01T23:45:30Z","document_type":"article","news_desk":null,"section_name":"Business Day","subsection_name":null,"byline":{"person":[],"original":"By REUTERS","organization":"REUTERS"},"type_of_material":"News","_id":"5819292195d0e022439c6800","word_count":"723","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/reuters\/2016\/11\/01\/sports\/soccer\/01reuters-soccer-champions-mci-fcb-guardiola.html","snippet":"Pep Guardiola savoured a memorable night as Manchester City beat his old club Barcelona, \"the best team in the world\", 3-1 on Tuesday with a display that hinted he may be building something special....","lead_paragraph":"Pep Guardiola savoured a memorable night as Manchester City beat his old club Barcelona, \"the best team in the world\", 3-1 on Tuesday with a display that hinted he may be building something special.","abstract":null,"print_page":null,"blog":[],"source":"Reuters","multimedia":[],"headline":{"main":"Guardiola Savours Beating 'Best Team in World' Barca","print_headline":"Guardiola Savours Beating 'Best Team in World' Barca"},"keywords":[],"pub_date":"2016-11-01T23:36:29Z","document_type":"article","news_desk":null,"section_name":"Sports","subsection_name":"Soccer","byline":{"person":[],"original":"By REUTERS","organization":"REUTERS"},"type_of_material":"News","_id":"5819270595d0e022439c67ff","word_count":"415","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/aponline\/2016\/11\/01\/sports\/ncaafootball\/ap-fbc-playoff-rankings.html","snippet":"Texas A&amp;M was ranked fourth behind Alabama, Clemson and Michigan in the season's first College Football Playoff rankings....","lead_paragraph":"Texas A&amp;M was ranked fourth behind Alabama, Clemson and Michigan in the season's first College Football Playoff rankings.","abstract":null,"print_page":null,"blog":[],"source":"AP","multimedia":[],"headline":{"main":"CFP Rankings: Texas A&M 4th Behind 'Bama, Clemson, Michigan","print_headline":"CFP Rankings: Texas A&M 4th Behind 'Bama, Clemson, Michigan"},"keywords":[],"pub_date":"2016-11-01T23:34:11Z","document_type":"article","news_desk":null,"section_name":"Sports","subsection_name":"College Football","byline":{"person":[],"original":"By THE ASSOCIATED PRESS","organization":"THE ASSOCIATED PRESS"},"type_of_material":"News","_id":"5819267595d0e022439c67fe","word_count":"824","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/reuters\/2016\/11\/01\/sports\/soccer\/01reuters-soccer-worldcup-tha-aus-australia-squad.html","snippet":"Australia talisman Tim Cahill will be rested for this month's World Cup qualifier against Thailand to allow him to fully recover from an Achilles complaint that ruled him out of domestic football last week....","lead_paragraph":"Australia talisman Tim Cahill will be rested for this month's World Cup qualifier against Thailand to allow him to fully recover from an Achilles complaint that ruled him out of domestic football last week.","abstract":null,"print_page":n ...
# entering
# <class 'requests.models.Response'>
# {"response":{"meta":{"hits":852,"time":52,"offset":20},"docs":[{"web_url":"http:\/\/www.nytimes.com\/2016\/11\/01\/sports\/world-series-score-cubs-indians.html","snippet":"An offensive outburst by the heart of Chicago\u2019s order gave Jake Arrieta plenty of room to beat the Indians, who struggled defensively and at the plate....","lead_paragraph":"An offensive outburst by the heart of Chicago\u2019s order gave Jake Arrieta plenty of room to beat the Indians, who struggled defensively and at the plate.","abstract":null,"print_page":null,"blog":[],"source":"The New York Times","multimedia":[{"width":190,"url":"images\/2016\/11\/02\/sports\/02wscubswin\/02wscubswin-thumbWide.jpg","height":126,"subtype":"wide","legacy":{"wide":"images\/2016\/11\/02\/sports\/02wscubswin\/02wscubswin-thumbWide.jpg","wideheight":"126","widewidth":"190"},"type":"image"},{"width":600,"url":"images\/2016\/11\/02\/sports\/02wscubswin\/02wscubswin-articleLarge.jpg","height":430,"subtype":"xlarge","legacy":{"xlargewidth":"600","xlarge":"images\/2016\/11\/02\/sports\/02wscubswin\/02wscubswin-articleLarge.jpg","xlargeheight":"430"},"type":"image"},{"width":75,"url":"images\/2016\/11\/02\/sports\/02wscubswin\/02wscubswin-thumbStandard-v2.jpg","height":75,"subtype":"thumbnail","legacy":{"thumbnailheight":"75","thumbnail":"images\/2016\/11\/02\/sports\/02wscubswin\/02wscubswin-thumbStandard-v2.jpg","thumbnailwidth":"75"},"type":"image"}],"headline":{"main":"World Series: Here\u2019s How the Chicago Cubs Won Game 6"},"keywords":[{"rank":"1","is_major":"N","name":"subject","value":"Baseball"},{"rank":"2","is_major":"N","name":"subject","value":"World Series"},{"rank":"3","is_major":"N","name":"organizations","value":"Chicago Cubs"},{"rank":"4","is_major":"N","name":"organizations","value":"Cleveland Indians"}],"pub_date":"2016-11-01T23:10:53Z","document_type":"article","news_desk":"Sports","section_name":"Sports","subsection_name":"Baseball","byline":{"person":[{"organization":"","role":"reported","firstname":"Benjamin","rank":1,"lastname":"HOFFMAN"},{"organization":"","role":"reported","firstname":"David","rank":2,"lastname":"WALDSTEIN"}],"original":"By BENJAMIN HOFFMAN and DAVID WALDSTEIN"},"type_of_material":"News","_id":"5819210495d0e022439c67f6","word_count":"3948","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/reuters\/2016\/11\/01\/business\/01reuters-saudi-aramco.html","snippet":"Saudi Aramco expects oil prices to rebound in the first half of 2017 and for demand to remain healthy following two years of painfully low prices, the state-owned producer's Chief Executive Officer Amin Nasser said on Tuesday....","lead_paragraph":"Saudi Aramco expects oil prices to rebound in the first half of 2017 and for demand to remain healthy following two years of painfully low prices, the state-owned producer's Chief Executive Officer Amin Nasser said on Tuesday.","abstract":null,"print_page":null,"blog":[],"source":"Reuters","multimedia":[],"headline":{"main":"Saudi Aramco CEO Expects Oil Price Rise in 1st-Half 2017","print_headline":"Saudi Aramco CEO Expects Oil Price Rise in 1st-Half 2017"},"keywords":[],"pub_date":"2016-11-01T23:09:27Z","document_type":"article","news_desk":null,"section_name":"Business Day","subsection_name":null,"byline":{"person":[],"original":"By REUTERS","organization":"REUTERS"},"type_of_material":"News","_id":"581920b195d0e022439c67f5","word_count":"450","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/video\/us\/politics\/100000004742871\/clinton-redirects-aim-at-trump.html","snippet":"After days of talking about the F.B.I. director, James B. Comey, Hillary Clinton refocused on Donald J. Trump and his treatment of women....","lead_paragraph":"After days of talking about the F.B.I. director, James B. Comey, Hillary Clinton refocused on Donald J. Trump and his treatment of women.","abstract":null,"print_page":null,"blog":[],"source":null,"multimedia":[{"width":190,"url":"images\/2016\/11\/01\/us\/01video-clinton1 ...
# entering
# <class 'requests.models.Response'>
# {"response":{"meta":{"hits":852,"time":67,"offset":30},"docs":[{"web_url":"http:\/\/www.nytimes.com\/2016\/11\/02\/business\/international\/timeline-glaxo-fallout-china.html","snippet":"A whistle-blower working for GlaxoSmithKline began sending anonymous tips about fraud and corruption at its operation in China. Here\u2019s what happened next....","lead_paragraph":"A whistle-blower working for GlaxoSmithKline began sending anonymous tips about fraud and corruption at its operation in China. Here\u2019s what happened next.","abstract":null,"print_page":"9","blog":[],"source":"The New York Times","multimedia":[{"width":190,"url":"images\/2016\/10\/15\/business\/chinaglaxo-timeline\/chinaglaxo-timeline-thumbWide.jpg","height":126,"subtype":"wide","legacy":{"wide":"images\/2016\/10\/15\/business\/chinaglaxo-timeline\/chinaglaxo-timeline-thumbWide.jpg","wideheight":"126","widewidth":"190"},"type":"image"},{"width":600,"url":"images\/2016\/10\/15\/business\/chinaglaxo-timeline\/chinaglaxo-timeline-articleLarge.jpg","height":316,"subtype":"xlarge","legacy":{"xlargewidth":"600","xlarge":"images\/2016\/10\/15\/business\/chinaglaxo-timeline\/chinaglaxo-timeline-articleLarge.jpg","xlargeheight":"316"},"type":"image"},{"width":75,"url":"images\/2016\/10\/15\/business\/chinaglaxo-timeline\/chinaglaxo-timeline-thumbStandard.jpg","height":75,"subtype":"thumbnail","legacy":{"thumbnailheight":"75","thumbnail":"images\/2016\/10\/15\/business\/chinaglaxo-timeline\/chinaglaxo-timeline-thumbStandard.jpg","thumbnailwidth":"75"},"type":"image"}],"headline":{"main":"Glaxo\u2019s Fallout in China","print_headline":"Hearing the Whistle,  Not Ending the Fraud"},"keywords":[{"rank":"1","is_major":"N","name":"subject","value":"vis-multimedia"},{"rank":"2","is_major":"N","name":"organizations","value":"GlaxoSmithKline PLC"},{"rank":"3","is_major":"N","name":"subject","value":"Bribery and Kickbacks"},{"rank":"4","is_major":"N","name":"subject","value":"Whistle-Blowers"},{"rank":"5","is_major":"N","name":"subject","value":"Frauds and Swindling"}],"pub_date":"2016-11-01T22:57:45Z","document_type":"article","news_desk":"Business","section_name":"Business Day","subsection_name":"International Business","byline":{"person":[{"organization":"","role":"reported","firstname":"David","rank":1,"lastname":"BARBOZA"}],"original":"By DAVID BARBOZA"},"type_of_material":"News","_id":"58191df095d0e022439c67ec","word_count":"562","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/reuters\/2016\/11\/01\/us\/01reuters-oklahoma-crime.html","snippet":"An Oklahoma man faces charges of stealing a police vehicle after he posted videos during a high-speed ride in a patrol car where he says: \"I can't believe I'm doing this.\"...","lead_paragraph":"An Oklahoma man faces charges of stealing a police vehicle after he posted videos during a high-speed ride in a patrol car where he says: \"I can't believe I'm doing this.\" ","abstract":null,"print_page":null,"blog":[],"source":"Reuters","multimedia":[],"headline":{"main":"Oklahoma Man Accused of Stealing Police Car After Posting Video of Joyride","print_headline":"Oklahoma Man Accused of Stealing Police Car After Posting Video of Joyride"},"keywords":[],"pub_date":"2016-11-01T22:57:30Z","document_type":"article","news_desk":null,"section_name":"U.S.","subsection_name":null,"byline":{"person":[],"original":"By REUTERS","organization":"REUTERS"},"type_of_material":"News","_id":"58191de495d0e022439c67eb","word_count":"290","slideshow_credits":null},{"web_url":"http:\/\/www.nytimes.com\/2016\/11\/02\/nyregion\/city-unveils-possible-routes-for-streetcar-in-brooklyn-and-queens.html","snippet":"The route would have a dedicated lane in traffic where possible, an effort that could prompt anger among drivers over the loss of street space and parking....","lead_paragraph":"The route would have a dedicated lane in traffic where possible, an effort that could prompt anger among drivers over the loss of street space and parking.","abstrac ...
# entering
# <class 'requests.models.Response'>
#
# <class 'requests.models.Response'>
# {"message":"API rate limit exceeded"}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-58ca95c5b364> in <module>()
# ----> 1 main()
#
# <ipython-input-7-a79d47694d2a> in main()
#      16         date = date.strftime("%Y%m%d")
#      17         logging.info("Working on %s." % date)
# ---> 18         getArticles(date,api_key,json_file_path)
#      19         #parseArticles(date, csv_file_name, json_file_path)
#      20 #     except:
#
# <ipython-input-4-73c21bdb8a8b> in getArticles(date, api_key, json_file_path)
#      26             #r = content["response"]
#      27             #print(r)
# ---> 28             if len(articles["response"]["docs"]) >= 1:
#      29                 print("entering")
#      30                 json_file_name = getJsonFileName(date,page, json_file_path)
#
# KeyError: 'response'
